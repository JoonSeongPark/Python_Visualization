# %% [markdown]
# <br>
# <p style="text-align: right; font-weight: bold; font-size: 50px"> Seaborn. </p>
# <p style="text-align: right; font-weight: bold; font-size: 15px"> : Python data visualization library based on matplotlib</p>

# %% [markdown]
# <button type="button" style="float: right;"> 13기 디자인팀 박준성 </button>

# %% [markdown]
# ---

# %% [markdown]
# # Seaborn 이란?
#  <p style="text-align: right">[Seaborn Documentation](https://seaborn.pydata.org/index.html)  </p>
#  : matplotlib 기반의 다양한 색 테마, 차트 기능을 추가한 python 시각화 라이브러리
#  matplotlib에 없는 그래프(hitmap, countplot ...)를 가지고 있다.
#
#  <br>
#  <b>seaborn</b>은..
#  <br>
#  다양한 그래프를 <b>간단한 code</b>를 통해 구현이 가능하고,
#  보다 <b>다채로운 색채</b>를 지원해준다.
#
#  ## Seaborn Basic Steps
#  1. Data Preparing
#  2. Figure Aesthetics
#  3. Seaborn Plotting
#  4. Further Customizations
#  5. Show or Save Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset("tips") # 팁 데이터 불러오기
sns.set_style("whitegrid")

# lmplot은 변수 사이의 상관관계를 파악할 때 사용.
g = sns.lmplot(x = "tip", y = "total_bill", data = tips, aspect = 2)
g = (g.set_axis_labels("Tip","Total bill(U$D)"), g.set(xlim = (0,10), ylim = (0,100)))
plt.title("Relation between Bill & Tip")

plt.show(g)

# %% [markdown]
# ---

# %% [markdown]
# # 0. Install / Import Seaborn
#  : seaborn은 앞서 말했듯이, matplotlib 기반이므로 matplotlib도 함께 import한다.

# %% [markdown]
# ## Install
# <b>pip install seaborn
# conda install seaborn</b>
#
# ## Update
# 현재 최신 버전은 0.9.0
# <b>pip3 install seaborn==0.9.0</b>

# %% [markdown]
# ## Import

# %%
import matplotlib.pyplot as plot
import seaborn as sns

# %% [markdown]
# ---

# %% [markdown]
# # 1. Data Preparing
#
# ## 1-1. Make Data
#  : numpy를 이용하여 원하는 데이터 만들기

# %%
import pandas as pd
import numpy as np

uniform_data = np.random.rand(10, 12)
normal_dist_data = pd.DataFrame({'x': np.arange(1, 101), 'y': np.random.normal(0, 4, 100)})

# %% [markdown]
# ## 1-2. Seaborn Built-in Data
#  : " [seaborn github](https://github.com/mwaskom/seaborn-data) " 에 저장되어 있는 data를 불러오기
#  <br>
# - <b>sns.load_dataset</b> (name, cache=True, data_home=None, **kws)
#  <br>
#  원하는 데이터의 이름을 확인하여 name 부분에 입력하여 불러온다.

# %%
iris = sns.load_dataset("iris")    # IRIS data
titanic = sns.load_dataset("titanic")    # Titinic data
tips = sns.load_dataset("tips")    # Tip data
flights = sns.load_dataset("flights")    # Flight data

# %% [markdown]
# ## 1-3. Import Local Data
#  : pandas를 통해서 csv 불러오기
#  기존에 <b>pd.read_csv</b> 를 통해서 불러오는 방식이므로 코드 설명은 생략

# %% [markdown]
# ---

# %% [markdown]
# # 2. Figure Aesthetics
#  : figure의 특성을 세팅하기!
# ### ※ Subplot ???
#  : 한 화면에 여러 그래프를 나눠서 그려주는 기능으로 <b>plt.subplot(###)</b> 형태로 사용한다.
# <br>
# subplot 안에 3개의 숫자가 들어가는데,
# 앞의 두 숫자는 <b>'(# x #) 형태로 화면을 분할한다'</b>는 것을 의미한다.
# 마지막 숫자는 앞의 (# x #)형태의 <b>'화면 분할 중에 # 번째 칸'</b>을 의미한다.
# <br>
# <b>예시를 통해 이해해보자!</b>

# %%
plt.figure(figsize = (10,6))

sns.set() # 윗 내용에서 세팅한거 초기화

plt.subplot(221) # (2x2) 4칸으로 나눴을 때 1번 칸
plt.subplot(222) # (2x2) 4칸으로 나눴을 때 2번 칸
plt.subplot(212) # (2x2) 4칸으로 나눴을 때 2번 칸

plt.show()

# %% [markdown]
# <b>이해를 위해 조금 더 복잡한 예시를 확인해봅시다!</b>

# %%
plt.figure(figsize = (10,12))

plt.subplot(411)
plt.subplot(423)
plt.subplot(424)
plt.subplot(437)
plt.subplot(438)
plt.subplot(439)
plt.subplot(414)

plt.show()

# %% [markdown]
# <b>그렇다면, 각 plot에 그래프를 넣어보자!</b>

# %%
import numpy as np

sns.set_style("whitegrid")

arange = np.arange(0.01, np.pi, 0.01)

plt.figure(figsize = (10, 12))

plt.subplot(411)
plt.plot(arange, arange, 'r')
plt.grid()

plt.subplot(423)
plt.plot(arange, arange**2, 'k')
plt.grid()

plt.subplot(424)
plt.plot(arange, np.sqrt(arange), 'k')
plt.grid()

plt.subplot(437)
plt.plot(arange, np.sin(arange))
plt.grid()

plt.subplot(438)
plt.plot(arange, np.cos(arange))
plt.grid()

plt.subplot(439)
plt.plot(arange, np.tan(arange))
plt.grid()

plt.subplot(414)
plt.plot(arange, np.log(arange), 'orange')
plt.grid()

plt.show()

# %% [markdown]
# ### ※ Subplot's' ???
#  : plt.subplot과 plt.subplots는 사용하려는 기능은 같지만 조금 다르게 작용한다.
#  <b>'s'</b>가 붙으면 무엇이 달라지는지 살펴보자.
#  <br>
# - <b>plt.subplots</b> (nrows=1, ncols=1, sharex=False, sharey=False, squeeze=True, subplot_kw=None, gridspec_kw=None, **fig_kw)
#  <br>
#  사용하는 parameter는 위와 같고,
#  <b>return값</b>이 <b>'fig'</b>와 <b>'ax'</b>로 두 개의 값을 가진다.
#  - <b>fig:</b> Figure
#  - <b>ax:</b> Object or Array of Axes objects

# %%
# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# Creates just a figure and only one subplot
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')

# Creates two subplots and unpacks the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# %% [markdown]
#  다시 원래 내용인 <b>seaborn</b>으로 돌아가겠습니다.
#  <br>
#  우선, figure와 하나의 subplot을 생성합니다.

# %%
f, ax = plt.subplots(figsize = (5, 6))

# %% [markdown]
# ## 2-1. Seaborn Style
# - <b>sns.set_style</b> (style=None, rc=None)
# <br>
# 주로, style에 값을 입력. (None, darkgrid, whitegrid, dark, white, ticks...)

# %%
sns.set() # (Re)set the seaborn default

sns.set_style("whitegrid")
sns.set_style("ticks", {"xtick.major.size":8, "ytick.major.size":8})
sns.axes_style("whitegrid")
# Out:
# {'axes.axisbelow': True,
#  'axes.edgecolor': '.8',
#  'axes.facecolor': 'white',
#  'axes.grid': True,
#  'axes.labelcolor': '.15',
#  'axes.spines.bottom': True,
#  'axes.spines.left': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True,
#  'figure.facecolor': 'white',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'image.cmap': 'rocket',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'text.color': '.15',
#  'xtick.bottom': False,
#  'xtick.color': '.15',
#  'xtick.direction': 'out',
#  'xtick.top': False,
#  'ytick.color': '.15',
#  'ytick.direction': 'out',
#  'ytick.left': False,
#  'ytick.right': False}

# %% [markdown]
# ## 2-2. Context Functions
# : affect size of labels, lines, and other elements of the plot, but not the overall style.
# <br>
# - <b>sns.set_context</b> (context=None, font_scale=1, rc=None)
#  <b>context:</b> paper, notebook, talk, poster

# %%
sns.set_context("talk")

# %% [markdown]
# ## 2-3. Color Palette
#  : select and use color palettes that are suited to the kind of data.
#  <br>
# - <b>sns.set_palette</b> (palette, n_colors=None, desat=None, color_codes=False)
#  <br>
#  전반적인 setting을 정하는 경우로, palette에 적절한 키워드 입력.

# %%
sns.set_palette("dark")

# %% [markdown]
# - <b>sns.color_palette</b> (palette=None, n_colors=None, desat=None)
#  <br>
#  일시적으로 palette를 할당하는 경우.

# %%
sns.set()

# %%
sns.palplot(sns.color_palette("muted"))

# %%
sns.palplot(sns.color_palette("Blues_d"))

# %% [markdown]
#  - my_palette = ("color", "color", "color", "color", "color", "color")
#  - <b>sns.set_palette</b> (my_palette)
#  - <b>sns.color_palette</b> (my_palette)
#  <br>
#  직접 palette를 지정하여 할당하는 경우.

# %%
my_palette = ("#f1c40f", "#f39c12", "#e67e22", "#d35400", "#c0392b")
sns.palplot(sns.color_palette(my_palette))

# %% [markdown]
# <b>※ 설명하느라 리셋한 세팅들을 다시 불러오겠습니다.</b>

# %%
sns.set() # (Re)set the seaborn default

sns.set_style("whitegrid")
sns.set_style("ticks", {"xtick.major.size":8, "ytick.major.size":8})
sns.axes_style("whitegrid")

sns.set_context("talk")

sns.set_palette("dark")

# %% [markdown]
# ---

# %% [markdown]
# # 3. Seaborn Plotting
#  : 데이터에 맞는 적절한 plot을 선택하기

# %% [markdown]
# ## 3-1. Axis Grids
# <br>
# - <b>sns.FacetGrid</b> (data, row=None, col=None, hue=None, col_wrap=None, sharex=True, sharey=True, height=3, aspect=1, palette=None, row_order=None, col_order=None, hue_order=None, hue_kws=None, dropna=True, legend_out=True, despine=True, margin_titles=False, xlim=None, ylim=None, subplot_kws=None, gridspec_kws=None, size=None)
# <br>
# 한 면에 grid를 나누는 방법으로, <b>data, row, col</b> 이면 충분하다.

# %%
g = sns.FacetGrid(titanic, col="survived", row="sex")

# %% [markdown]
# grid를 위와 같이 변수에 세팅하고, <b>.map( )</b>을 통해 보고싶은 정보를 원하는 시각화 방법으로 입력한다.

# %%
g = sns.FacetGrid(titanic, col="survived", row="sex")
g.map(plt.hist, "age")

# %%
g = sns.FacetGrid(tips, col = "time", row = "smoker")
g.map(plt.scatter, "total_bill", "tip", s=9)

# %%
kws = dict(s=50, linewidth=.5, edgecolor="w")
g = sns.FacetGrid(tips, col="sex", hue="time", palette="Set1", hue_order=["Dinner", "Lunch"])
g = (g.map(plt.scatter, "total_bill", "tip", **kws).add_legend())

# %% [markdown]
# ## 3-2. Categorical Plots

# %% [markdown]
# ### Scatterplot
# - <b>sns.stripplot</b> (x=None, y=None, hue=None, data=None, order=None, hue_order=None, jitter=True, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)
# <br>
# <b>한 변수가 categorical</b>인 경우에 <b>Scatterplot</b>을 그리는 방법

# %%
sns.stripplot(data=iris, x="species", y="petal_length")

# %% [markdown]
# - <b>sns.swarmplot</b> (x=None, y=None, hue=None, data=None, order=None, hue_order=None, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)
# <br>
# <b>sns.stripplot</b>과 유사하다.
# <b>'points가 겹치지 않는다'</b>는 차이점이 있어서, <b>분포를 파악</b>하기가 좋다.

# %%
sns.swarmplot(data=iris, x="species", y="petal_length")

# %% [markdown]
# ### Bar Chart
# - <b>sns.barplot</b> (x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=function mean, ci=95, n_boot=1000, units=None, orient=None, color=None, palette=None, saturation=0.75, errcolor='.26', errwidth=None, capsize=None, dodge=True, ax=None, **kwargs)
# <br>
# <b>barchart</b>를 통해서 <b>추정값</b>과 <b>신뢰구간</b>을 나타내는 방법

# %%
sns.barplot(data=titanic, x="sex", y="survived", hue="class")

# %% [markdown]
# ### Count Plot
# - <b>sns.countplot</b> (x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, dodge=True, ax=None, **kwargs)
# <br>
# 각 categorical 변수에 대하여 <b>관측치 수</b>를 <b>bar 형태</b>로 나타내는 것.

# %%
sns.countplot(data=titanic, x="deck", palette="Greens_d")

# %% [markdown]
# ### Point Plot
# - <b>sns.pointplot</b> (x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=function mean, ci=95, n_boot=1000, units=None, markers='o', linestyles='-', dodge=False, join=True, scale=1, orient=None, color=None, palette=None, errwidth=None, capsize=None, ax=None, **kwargs)
# <br>
# categorical 변수 기준으로 <b>평균 값</b>과 <b>신뢰구간</b>을 나타내준다.
# points가 <b>선으로 연결</b>되어 시각적으로 비교하기 좋다.

# %%
sns.pointplot(data=titanic, x="class", y="survived", hue="sex", palette={"male":"g","female":"m"}, markers=["^", "o"], linestyles=["-", "--"])

# %% [markdown]
# ### Boxplot
# - <b>sns.boxplot</b> (x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, notch=False, ax=None, **kwargs)
# <br>
# <b>boxplot</b>(설명 생략)을 그려준다.
# <br>
# ※ <b>orient</b>값을 <b>'v'</b>: vertical, <b>'h'</b>: horizontal 로 설정함에 따라 모양을 결정할 수 있다.

# %%
sns.boxplot(data=titanic, x="alive", y="age", hue="adult_male")
plt.legend(loc="upper left")

# %%
sns.boxplot(data=iris, orient="h")

# %% [markdown]
# ### Violinplot

# %% [markdown]
# - <b>sns.violinplot</b> (x=None, y=None, hue=None, data=None, order=None, hue_order=None, bw='scott', cut=2, scale='area', scale_hue=True, gridsize=100, width=0.8, inner='box', split=False, dodge=True, orient=None, linewidth=None, color=None, palette=None, saturation=0.75, ax=None, **kwargs)
# <br>
# <b>Violinplot</b>은 <b>Boxplot</b>과 <b>Kernel Density Estimate</b>를 조합한 plot이다.
# <b>Boxplot</b>과 달리 사각형이 아닌 <b>각 data points</b>를 나타낸다.
# <br>
# <b>※ Kernel Density Estimate</b>
# : 관측 데이터 각각마다 중심으로 하는 커널 함수를 생성하고, 이렇게 만들어진 커널 함수들을 모두 더한 후 전체 데이터 개수로 나누어 하나의 밀도함수를 만드는 방법.
# 사용한 커널함수에 따라 모양이 달라진다.
# 히스토그램 확률밀도함수를 smoothing한 것으로 생각하면 이해하기 쉽다.

# %%
sns.violinplot(data=titanic, x="age", y="sex", hue="survived")

# %% [markdown]
# ## 3-3. Regression Plots

# %% [markdown]
# - <b>sns.regplot</b> (x, y, data=None, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=False, dropna=True, x_jitter=None, y_jitter=None, label=None, color=None, marker='o', scatter_kws=None, line_kws=None, ax=None)
# <br>
# <b>Linear Regression</b>에 데이터를 fit 시켜서 그리는 방법.

# %%
ax = sns.regplot(x="total_bill", y="tip", data=tips)

# %% [markdown]
# - <b>sns.lmplot</b> (x, y, data, hue=None, col=None, row=None, palette=None, col_wrap=None, height=5, aspect=1, markers='o', sharex=True, sharey=True, hue_order=None, col_order=None, row_order=None, legend=True, legend_out=True, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=False, x_jitter=None, y_jitter=None, scatter_kws=None, line_kws=None, size=None)
# <br>
# <b>replot()</b>과 <b>FacetGrid</b>의 합쳐진 형태로, 조건에 따른 Linear Regression을 보려고 할 때 사용하면 좋다.

# %%
sns.lmplot(data=iris, x="sepal_width", y="sepal_length", hue="species")
